# %%
import pandas as pd 
from pandas_profiling import ProfileReport
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('./results/sim_data_1.csv',index_col=0)
data.head()
# Out:
#       V1     V2     V3     V4     V5     V6     V7     V8     V9    V10   V11  \
# 1   2927   1044   2335   3388   4852  11406  15518  12748   9922   8330  3505
# 2   1952   2164   8922   9126   9842  12343  21543  15797  10793   8293  3380
# 3   2536   1851   5193   4373   4492   6039   7176   3887   2723   1971   973
# 4  27665  10160  14679  11232  12541  18152  23555  18284  15177  13343  7562
# 5   1729    447    557    283    277    303    394    299    227    240   148
#
#      V12
# 1   7150
# 2   7053
# 3   1937
# 4  15900
# 5    292

# %%
data.describe()
# Out:
#                   V1             V2            V3            V4            V5  \
# count   13164.000000   13164.000000  1.316400e+04  1.316400e+04  1.316400e+04
# mean     4209.277499    3441.314114  8.008407e+03  4.949393e+03  4.665378e+03
# std     14596.908683   14605.016327  3.616427e+04  2.120284e+04  1.978579e+04
# min         0.000000       0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        10.000000       7.000000  1.800000e+01  1.600000e+01  2.000000e+01
# 50%       548.000000     344.000000  7.160000e+02  5.830000e+02  6.405000e+02
# 75%      3781.000000    2671.500000  5.651000e+03  3.750000e+03  3.704000e+03
# max    897605.000000  978420.000000  2.409446e+06  1.345395e+06  1.202531e+06
#
#                  V6            V7            V8             V9           V10  \
# count  1.316400e+04  1.316400e+04  1.316400e+04   13164.000000  1.316400e+04
# mean   5.959713e+03  7.357531e+03  5.891474e+03    5381.032057  5.484228e+03
# ...

# %%
data_ori = pd.read_csv('./data/fly_data_embryos.csv', index_col = 0)
data_ori = data_ori[np.max(data_ori.values, axis = 1) > 0]
data_ori.describe()
# Out:
#          Embryos0002    Embryos0204   Embryos0406   Embryos0608   Embryos0810  \
# count   13164.000000   13164.000000  1.316400e+04  1.316400e+04  1.316400e+04
# mean     4209.845260    3441.474552  8.008124e+03  4.949637e+03  4.665803e+03
# std     13807.063134   15163.024063  3.612983e+04  2.118964e+04  2.005857e+04
# min         0.000000       0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%         2.000000       5.000000  1.400000e+01  1.200000e+01  1.800000e+01
# 50%       146.000000     200.000000  5.290000e+02  4.370000e+02  5.455000e+02
# 75%      4068.500000    2335.500000  5.524000e+03  3.623250e+03  3.534500e+03
# max    803339.000000  992748.000000  2.314580e+06  1.337788e+06  1.265408e+06
#
#         Embryos1012   Embryos1214   Embryos1416    Embryos1618   Embryos1820  \
# count  1.316400e+04  1.316400e+04  1.316400e+04   13164.000000  1.316400e+04
# mean   5.959567e+03  7.358035e+03  5.892875e+03    5382.195913  5.484586e+03
# ...

# %%
profile = ProfileReport(data, title="simulated data report")

# %%
profile.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
#    df_index     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0         1   2927   1044   2335   3388   4852  11406  15518  12748   9922
# 1         2   1952   2164   8922   9126   9842  12343  21543  15797  10793
# 2         3   2536   1851   5193   4373   4492   6039   7176   3887   2723
# 3         4  27665  10160  14679  11232  12541  18152  23555  18284  15177
# 4         5   1729    447    557    283    277    303    394    299    227
# 5         6    124   1111   4042   1198    510    240    183    106     58
# 6         7     33     33     78     77    128    335    928   2428   4290
# 7         8     17      8     32     25     48    195    403    741    697
# 8         9   6817   2503   3607   2825   2977   4409   5679   4403   3628
# 9        10      9     11     31     25     49    123    423    983   1719
#
#      V10   V11    V12
# 0   8330  3505   7150
# 1   8293  3380   7053
# ...

# %% [markdown]
# # Try with the log transform

# %%
for col in data.columns :
    data[col] = np.log(data[col]+1)

# %%
data.describe()
# Out:
#          SRX008333    SRX008334    SRX008331    SRX008332
# count  4956.000000  4956.000000  4956.000000  4956.000000
# mean      3.311976     3.247458     3.740717     3.701701
# std       1.619367     1.613226     1.354900     1.354008
# min       0.000000     0.000000     0.000000     0.000000
# 25%       2.484907     2.484907     2.995732     2.944439
# 50%       3.465736     3.401197     3.795426     3.761200
# 75%       4.418841     4.343805     4.595120     4.574711
# max       9.247636     8.995165     9.888780     9.831239

# %%
profile = ProfileReport(data, title="Human cells report")
profile.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
